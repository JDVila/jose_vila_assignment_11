# %%
# %matplotlib notebook

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
import sklearn.metrics as metrics

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import precision_score

# %%
from sklearn.metrics import recall_score

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import roc_curve

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import cross_validate

# %%
insurance = pd.read_csv('travel_insurance.csv')

# %%
insurance.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age
# 0    No       186    MALAYSIA      -29.0                  9.57      F   81
# 1    No       186    MALAYSIA      -29.0                  9.57      F   71
# 2    No        65   AUSTRALIA      -49.5                 29.70    NaN   32
# 3    No        60   AUSTRALIA      -39.6                 23.76    NaN   32
# 4    No        79       ITALY      -19.8                 11.88    NaN   41

# %%
insurance['Agency'].unique()
# Out:
# array(['CBH', 'CWT', 'JZI', 'KML', 'EPX', 'C2B', 'JWT', 'RAB', 'SSI',
#        'ART', 'CSR', 'CCR', 'ADM', 'LWC', 'TTW', 'TST'], dtype=object)

# %%
insurance['Agency Type'].unique()
# Out:
# array(['Travel Agency', 'Airlines'], dtype=object)

# %%
insurance['Distribution Channel'].unique()
# Out:
# array(['Offline', 'Online'], dtype=object)

# %%
insurance['Product Name'].unique()
# Out:
# array(['Comprehensive Plan', 'Rental Vehicle Excess Insurance',
#        'Value Plan', 'Basic Plan', 'Premier Plan',
#        '2 way Comprehensive Plan', 'Bronze Plan', 'Silver Plan',
#        'Annual Silver Plan', 'Cancellation Plan',
#        '1 way Comprehensive Plan', 'Ticket Protector', '24 Protect',
#        'Gold Plan', 'Annual Gold Plan',
#        'Single Trip Travel Protect Silver',
#        'Individual Comprehensive Plan',
#        'Spouse or Parents Comprehensive Plan',
#        'Annual Travel Protect Silver',
#        'Single Trip Travel Protect Platinum',
#        'Annual Travel Protect Gold', 'Single Trip Travel Protect Gold',
#        'Annual Travel Protect Platinum', 'Child Comprehensive Plan',
#        'Travel Cruise Protect', 'Travel Cruise Protect Family'],
#       dtype=object)

# %%
insurance['Claim'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
insurance['Duration'].unique()
# Out:
# array([ 186,   65,   60,   79,   66,   47,   63,   57,   33,    1,   53,
#           5,   39,    6,   48,   11,    3,   14,  136,   12,    7,  190,
#         364,   29,   28,  153,    4,   54,   24,    9,   45,   35,    8,
#         183,   36,   38,   13,   27,   16,   19,   18,  189,  105,   23,
#          15,  180,   90,   91,    2,   17,   10,  279,   92,   22,   64,
#          37,   31,   41,  126,   50,   55,  181,   76,   43,   56,   20,
#         164,   26,  152,   30,   32,  111,   34,  201,   62,   81,   42,
#          49,  124,  118,   52,   59,   73,   21,   25,   94,   46,   82,
#          40,  130,  388,  369,  368,  114,   85,  133,  103,  110,  147,
#         306,   75,   83,   70,  104,  131,  202,  179,   61,  365,  374,
#         386,   86,  100,  244,   99,  108,  277,  107,   87,  276,  123,
#         122,  148,  278,  204,  112,   78,   97,  142,  351,   68,  163,
#         197,   95,  125,   51,   69,   44,   71,   72,  178,   80,  150,
#          74,  171,  127,  160,  168,  158,  325,  116,  215,  149,  212,
#         282,  174,    0,  155,   67,  101,  135,   93,  328,  106,   77,
#         151,  198,  146,  266,  102,  273,  144,  175,  274,  275,   58,
#         113,  154,  117,  140,   84,  327,  115,  165,  143,  367,  159,
#          96,   98,   89,  173,  230,  269,  132,  366,  109,  192,  169,
#         268,  271,  270,  166,  431,  129,   88,  263,  185,  242,  128,
#         233,  203,  145,  170,  239,  191,  156,  182,  283,  281,  267,
#         121,  326,  370,  321,  120,  255,  403,  392,  161,  167,  288,
#         141,  223,  240,  265,  187,  397,  378,  139,  172,  229,  119,
#         134,  235, 4881,  206,  262,  261,  237,  309,  391,  137,  259,
#         243,  342,  390,  389,  157,  375,  210,  264,  200,  254,  221,
#         199,  193,  214,  218,  304,  194,  162,  250,  249,  227,  226,
#         228,  385,  246,  211,  248,  371,  387,  376,  138,  245,  377,
#         213,  417,  331,  177,  406,  207,  241,  295,  319, 4857,  373,
#         432,  208,  236,  419,  400,  196,  381,  232,  300,  314,  290,
#         176, 4847,  311,  225,  318, 4844,  184,  287,  222,  238,  310,
#         285,  216,  380,  289,  305,  384,  220,  296,  224,  209,  219,
#         382,  317,  286,  217,  407,  302,  291,  297,  260, 4831,  234,
#         205, 4829,  294,  299,  383,  324,  257,  427,  293,  284,  740,
#         334,  312,  292,  247,   -2,  303,  280, 4815,  395,  252,  253,
#         256,  195,  330,  316,  307,  323,  322,  188,  231,  372,  399,
#         315,  329,  272,  379,  411,  251,  258, 4784,  402,  436,  409,
#         547,  396,  457,  393,  394,  401,  426,  487,  408,  361,  398,
#        4738, 4736,  421,  313,  298,  456,  416,  440,  529,  461,  418,
#         420,  404,  428,  413, 4685,  430, 4652,  448,  465,  301,  478,
#         497,  405,  422,  352,  350,  545,  508,  412,  415,  437,  474,
#         441,  332, 4609,  459,   -1,  435,  472,  410,  424,  531,  434,
#        4580,  490,  494,  466,  512,  519,  444,  423,  425,  445,  414,
#         463,  433,  450,  488])

# %%
insurance['Net Sales'].unique()
# Out:
# array([-29.  , -49.5 , -39.6 , ...,   1.74, 388.8 ,  11.58])

# %%
insurance['Commision (in value)'].unique()
# Out:
# array([ 9.57, 29.7 , 23.76, ..., 21.63, 97.2 ,  3.25])

# %%
insurance['Gender'].unique()
# Out:
# array(['F', nan, 'M'], dtype=object)

# %%
insurance['Age'].unique()
# Out:
# array([ 81,  71,  32,  41,  44,  29,  37, 118,  47,  48,  64,  36,  53,
#         43,  58,  25,  34,  26,  30,  33,  35,  31,  61,  20,  46,  49,
#         50,  62,  65,  24,  40,  21,  66,  57,  45,  52,  60,  27,  23,
#         39,  59,  28,  67,  38,  72,  51,  55,  54,  69,  22,  78,  42,
#         70,  68,  77,  63,  56,  79,  76,  16,  14,  73,  18,  19,  74,
#         85,  84,  13,  75,  87,  80,  83,  12,  10,   8,  17,  15,   9,
#         11,  86,   3,  82,   1,   5,  88,   2,   4,   0,   7])

# %%
insurance.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  63326.000000  63326.000000          63326.000000  63326.000000
# mean      49.317074     40.702018              9.809992     39.969981
# std      101.791566     48.845637             19.804388     14.017010
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.530000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000

# %% [markdown]
# ### Step 01 - Clean Up NaN Values

# %%
insurance.loc[insurance['Gender'].isna()]
# Out:
#       Agency    Agency Type Distribution Channel  \
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# 6        CWT  Travel Agency               Online
# 7        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63309    SSI       Airlines               Online
# 63310    SSI       Airlines               Online
# 63311    SSI       Airlines               Online
# 63312    SSI       Airlines               Online
# 63313    SSI       Airlines               Online
#
#                           Product Name Claim  Duration    Destination  \
# 2      Rental Vehicle Excess Insurance    No        65      AUSTRALIA
# 3      Rental Vehicle Excess Insurance    No        60      AUSTRALIA
# 4      Rental Vehicle Excess Insurance    No        79          ITALY
# 6      Rental Vehicle Excess Insurance    No        47  UNITED STATES
# 7      Rental Vehicle Excess Insurance    No        63      AUSTRALIA
# ...                                ...   ...       ...            ...
# 63309                 Ticket Protector    No        41      SINGAPORE
# 63310                 Ticket Protector    No        69      SINGAPORE
# 63311                 Ticket Protector    No        96      SINGAPORE
# 63312                 Ticket Protector    No        61      SINGAPORE
# 63313                 Ticket Protector    No        60      SINGAPORE
#
#        Net Sales  Commision (in value) Gender  Age
# 2         -49.50                 29.70    NaN   32
# 3         -39.60                 23.76    NaN   32
# 4         -19.80                 11.88    NaN   41
# 6         -39.60                 23.76    NaN   32
# 7        -108.90                 65.34    NaN   29
# ...          ...                   ...    ...  ...
# 63309      11.58                  3.25    NaN   48
# 63310      12.87                  3.61    NaN   48
# 63311       5.92                  1.66    NaN   48
# 63312       6.56                  1.84    NaN   48
# 63313       2.64                  0.74    NaN   48
#
# [45107 rows x 11 columns]

# %%
insurance.loc[insurance['Gender'] == 'M'].count()
# Out:
# Agency                  9347
# Agency Type             9347
# Distribution Channel    9347
# Product Name            9347
# Claim                   9347
# Duration                9347
# Destination             9347
# Net Sales               9347
# Commision (in value)    9347
# Gender                  9347
# Age                     9347
# dtype: int64

# %%
insurance.loc[insurance['Gender'] == 'F'].count()
# Out:
# Agency                  8872
# Agency Type             8872
# Distribution Channel    8872
# Product Name            8872
# Claim                   8872
# Duration                8872
# Destination             8872
# Net Sales               8872
# Commision (in value)    8872
# Gender                  8872
# Age                     8872
# dtype: int64

# %%
insurance.count()
# Out:
# Agency                  63326
# Agency Type             63326
# Distribution Channel    63326
# Product Name            63326
# Claim                   63326
# Duration                63326
# Destination             63326
# Net Sales               63326
# Commision (in value)    63326
# Gender                  18219
# Age                     63326
# dtype: int64

# %%
insurance['Gender'] = insurance['Gender'].fillna('M')

# %%
insurance.loc[insurance['Gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [Agency, Agency Type, Distribution Channel, Product Name, Claim, Duration, Destination, Net Sales, Commision (in value), Gender, Age]
# Index: []

# %%
insurance.loc[insurance['Gender'] == 'F']
# Out:
#       Agency    Agency Type Distribution Channel        Product Name Claim  \
# 0        CBH  Travel Agency              Offline  Comprehensive Plan    No
# 1        CBH  Travel Agency              Offline  Comprehensive Plan    No
# 5        JZI       Airlines               Online          Value Plan    No
# 12       KML  Travel Agency               Online        Premier Plan    No
# 21       C2B       Airlines               Online         Bronze Plan    No
# ...      ...            ...                  ...                 ...   ...
# 63315    JZI       Airlines               Online          Basic Plan    No
# 63316    JZI       Airlines               Online          Basic Plan    No
# 63317    JZI       Airlines               Online          Basic Plan    No
# 63322    JZI       Airlines               Online          Basic Plan    No
# 63325    JZI       Airlines               Online          Basic Plan    No
#
#        Duration    Destination  Net Sales  Commision (in value) Gender  Age
# 0           186       MALAYSIA     -29.00                  9.57      F   81
# 1           186       MALAYSIA     -29.00                  9.57      F   71
# 5            66  UNITED STATES    -121.00                 42.35      F   44
# 12           53         NORWAY    -130.00                 49.40      F   48
# 21           12      SINGAPORE      46.15                 11.54      F   44
# ...         ...            ...        ...                   ...    ...  ...
# 63315        42      AUSTRALIA      22.00                  7.70      F   25
# 63316        42      AUSTRALIA      22.00                  7.70      F   25
# 63317        42      AUSTRALIA      22.00                  7.70      F   25
# 63322        58          CHINA      40.00                 14.00      F   40
# 63325        22      HONG KONG      26.00                  9.10      F   35
#
# [8872 rows x 11 columns]

# %%
insurance.loc[insurance['Gender'] == 'M']
# Out:
#       Agency    Agency Type Distribution Channel  \
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# 6        CWT  Travel Agency               Online
# 7        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63319    JZI       Airlines               Online
# 63320    JZI       Airlines               Online
# 63321    JZI       Airlines               Online
# 63323    JZI       Airlines               Online
# 63324    JZI       Airlines               Online
#
#                           Product Name Claim  Duration        Destination  \
# 2      Rental Vehicle Excess Insurance    No        65          AUSTRALIA
# 3      Rental Vehicle Excess Insurance    No        60          AUSTRALIA
# 4      Rental Vehicle Excess Insurance    No        79              ITALY
# 6      Rental Vehicle Excess Insurance    No        47      UNITED STATES
# 7      Rental Vehicle Excess Insurance    No        63          AUSTRALIA
# ...                                ...   ...       ...                ...
# 63319                       Basic Plan    No        10              CHINA
# 63320                       Basic Plan    No         5  BRUNEI DARUSSALAM
# 63321                       Basic Plan    No       111              JAPAN
# 63323                       Basic Plan    No         2           MALAYSIA
# 63324                       Basic Plan    No         3           VIET NAM
#
#        Net Sales  Commision (in value) Gender  Age
# 2          -49.5                 29.70      M   32
# 3          -39.6                 23.76      M   32
# 4          -19.8                 11.88      M   41
# 6          -39.6                 23.76      M   32
# 7         -108.9                 65.34      M   29
# ...          ...                   ...    ...  ...
# 63319       35.0                 12.25      M   51
# 63320       18.0                  6.30      M   27
# 63321       35.0                 12.25      M   31
# 63323       18.0                  6.30      M   57
# 63324       18.0                  6.30      M   63
#
# [54454 rows x 11 columns]

# %%
insurance.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  63326.000000  63326.000000          63326.000000  63326.000000
# mean      49.317074     40.702018              9.809992     39.969981
# std      101.791566     48.845637             19.804388     14.017010
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.530000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000

# %% [markdown]
# ### Step 02 - Encode Categorical Values

# %%
ord_enc = OrdinalEncoder()

# %%
insurance['Agency_code'] = ord_enc.fit_transform(insurance[['Agency']])

# %%
insurance[['Agency_code', 'Agency']].head(5)
# Out:
#    Agency_code Agency
# 0          3.0    CBH
# 1          3.0    CBH
# 2          6.0    CWT
# 3          6.0    CWT
# 4          6.0    CWT

# %%
insurance['Agency Type_code'] = ord_enc.fit_transform(insurance[['Agency Type']])

# %%
insurance[['Agency Type_code', 'Agency Type']].head(6)
# Out:
#    Agency Type_code    Agency Type
# 0               1.0  Travel Agency
# 1               1.0  Travel Agency
# 2               1.0  Travel Agency
# 3               1.0  Travel Agency
# 4               1.0  Travel Agency
# 5               0.0       Airlines

# %%
insurance['Distribution Channel_code'] = ord_enc.fit_transform(insurance[['Distribution Channel']])

# %%
insurance[['Distribution Channel_code', 'Distribution Channel']].head(5)
# Out:
#    Distribution Channel_code Distribution Channel
# 0                        0.0              Offline
# 1                        0.0              Offline
# 2                        1.0               Online
# 3                        1.0               Online
# 4                        1.0               Online

# %%
insurance['Product Name_code'] = ord_enc.fit_transform(insurance[['Product Name']])

# %%
insurance[['Product Name_code', 'Product Name']].head(5)
# Out:
#    Product Name_code                     Product Name
# 0               12.0               Comprehensive Plan
# 1               12.0               Comprehensive Plan
# 2               16.0  Rental Vehicle Excess Insurance
# 3               16.0  Rental Vehicle Excess Insurance
# 4               16.0  Rental Vehicle Excess Insurance

# %%
insurance['Claim_code'] = ord_enc.fit_transform(insurance[['Claim']])

# %%
insurance[['Claim_code', 'Claim']].head(25)
# Out:
#     Claim_code Claim
# 0          0.0    No
# 1          0.0    No
# 2          0.0    No
# 3          0.0    No
# 4          0.0    No
# 5          0.0    No
# 6          0.0    No
# 7          0.0    No
# 8          0.0    No
# 9          0.0    No
# 10         0.0    No
# 11         0.0    No
# 12         0.0    No
# 13         0.0    No
# 14         0.0    No
# 15         0.0    No
# 16         0.0    No
# 17         0.0    No
# 18         0.0    No
# 19         0.0    No
# 20         0.0    No
# 21         0.0    No
# 22         0.0    No
# 23         1.0   Yes
# 24         0.0    No

# %%
insurance['Destination_code'] = ord_enc.fit_transform(insurance[['Destination']])

# %%
insurance[['Destination_code', 'Destination']].head(5)
# Out:
#    Destination_code Destination
# 0              79.0    MALAYSIA
# 1              79.0    MALAYSIA
# 2               4.0   AUSTRALIA
# 3               4.0   AUSTRALIA
# 4              61.0       ITALY

# %%
insurance['Gender_code'] = ord_enc.fit_transform(insurance[['Gender']])

# %%
insurance[['Gender_code', 'Gender']].head(5)
# Out:
#    Gender_code Gender
# 0          0.0      F
# 1          0.0      F
# 2          1.0      M
# 3          1.0      M
# 4          1.0      M

# %%
insurance.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age  \
# count  63326.000000  63326.000000          63326.000000  63326.000000
# mean      49.317074     40.702018              9.809992     39.969981
# std      101.791566     48.845637             19.804388     14.017010
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.530000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000
#
#         Agency_code  Agency Type_code  Distribution Channel_code  \
# count  63326.000000      63326.000000               63326.000000
# mean       6.654913          0.724331                   0.982519
# std        2.371884          0.446854                   0.131056
# min        0.000000          0.000000                   0.000000
# 25%        6.000000          0.000000                   1.000000
# 50%        7.000000          1.000000                   1.000000
# 75%        7.000000          1.000000                   1.000000
# max       15.000000          1.000000                   1.000000
#
#        Product Name_code    Claim_code  Destination_code   Gender_code
# count       63326.000000  63326.000000      63326.000000  63326.000000
# mean            9.292029      0.014639         85.257682      0.859900
# std             6.642143      0.120102         42.031838      0.347094
# min             0.000000      0.000000          0.000000      0.000000
# 25%             1.000000      0.000000         56.000000      1.000000
# 50%            10.000000      0.000000         88.000000      1.000000
# 75%            14.000000      0.000000        118.000000      1.000000
# max            25.000000      1.000000        148.000000      1.000000

# %%
insurance = insurance.drop(insurance[insurance['Duration'] > insurance['Duration'].mean() + (insurance['Duration'].std()*3)].index)

# %%
insurance = insurance.drop(insurance[insurance['Net Sales'] > insurance['Net Sales'].mean() + (insurance['Net Sales'].std()*3)].index)

# %%
insurance = insurance.drop(insurance[insurance['Commision (in value)'] > insurance['Commision (in value)'].mean() + (insurance['Commision (in value)'].std()*3)].index)

# %%
insurance = insurance.drop(insurance[insurance['Age'] > insurance['Age'].mean() + (insurance['Age'].std()*3)].index)

# %%
insurance = insurance.drop(insurance[insurance['Destination_code'] > insurance['Destination_code'].mean() + (insurance['Destination_code'].std()*3)].index)

# %% [markdown]
# ### Step 03 - Create and Train the Logistic Regression Model

# %%
X = insurance.drop(['Agency', 'Agency Type', 'Distribution Channel', 'Product Name', 'Claim', 'Destination', 'Gender'], axis=1)

# %%
y = insurance['Claim_code']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=123)

# %%
lr_model = LogisticRegression(C=1e6, max_iter=1000)

# %%
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1000000.0, max_iter=1000)

# %%
y_pred_lg = lr_model.predict(X_train)

# %%
selection = 'Net Sales'

# %%
plt.scatter(X_test[selection], y_test, color='b', label='Test Set')
m, b = np.polyfit(X_train[selection], y_pred_lg, 1)
plt.plot(X_train[selection], m*X_train[selection]+b, color='r')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Step 04 - Test Score, Accuracy, Precision, Confusion Matrix, ROC Curve, MSE, MAE, and Cross-Validation

# %%
lr_model.score(X_test, y_test)
# Out:
# 1.0

# %%
mse_lr = metrics.mean_squared_error(y_true=y_test, y_pred=y_pred_lg)

# %%
mse_lr
# Out:
# 0.022510255437967527

# %%
accuracy_lr = accuracy_score(y_true=y_test, y_pred=y_pred_lg)

# %%
accuracy_lr
# Out:
# 0.9774897445620325

# %%
precision_lr = precision_score(y_test, y_pred_lg)

# %%
precision_lr
# Out:
# 0.014367816091954023

# %%
recall_lr = recall_score(y_test, y_pred_lg)

# %%
recall_lr
# Out:
# 0.015873015873015872

# %%
def CM(y_true, y_pred):
    M = confusion_matrix(y_true, y_pred)
    out = pd.DataFrame(M, index=['Obs Claim Yes', 'Obs Claim No'], columns=['Pred Claim Yes', 'Pred Claim No'])
    return out

# %%
threshold = 0.5

# %%
y_pred_prob = lr_model.predict_proba(X_test)[:,1]

# %%
y_pred_cm = (y_pred_prob > threshold).astype(int)

# %%
CM(y_test, y_pred_cm)
# Out:
#                Pred Claim Yes  Pred Claim No
# Obs Claim Yes           28694              0
# Obs Claim No                0            315

# %%
fpr, tpr, ths = roc_curve(y_train, y_pred_prob)

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(fpr, tpr)
ax.set_title('ROC curve', fontsize=16)
ax.set_xlabel('False positive rate', fontsize=14)
ax.set_ylabel('Recall, true negative rate', fontsize=14)
ax.grid;
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fpr, tpr, ths = roc_curve(y_test, y_pred_prob)

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(fpr, tpr)
ax.set_title('ROC curve', fontsize=16)
ax.set_xlabel('False positive rate', fontsize=14)
ax.set_ylabel('Recall, true negative rate', fontsize=14)
ax.grid;
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
numerical_features = ['Duration', 'Net Sales', 'Commision (in value)', 'Age', 'Agency_code', 'Agency Type_code', 'Distribution Channel_code', 'Product Name_code', 'Destination_code', 'Gender_code']

# %%
mae_lr = mean_absolute_error(y_true=y_test, y_pred = y_pred_lg)

# %%
mae_lr
# Out:
# 0.022510255437967527

# %%
scaler = StandardScaler()

# %%
scaler.fit(X[numerical_features])
# Out:
# StandardScaler()

# %%
X.loc[:,numerical_features] = scaler.fit_transform(X[numerical_features])

# %%
ml_reg = LinearRegression();

# %%
cv_results = cross_validate(ml_reg, X, y, scoring='neg_mean_absolute_error', cv=10)

# %%
scores = -1*cv_results['test_score']

# %%
scores.mean()
# Out:
# 3.9281238016468604e-16
